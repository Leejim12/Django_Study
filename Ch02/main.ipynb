# %% [markdown]
# # Ch02 파이썬 웹 표준 라이브러리
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### urllib 패키지
# - 웹 클라이언트 작성 시 사용되는 모듈들 들어있음.
# - http.client 모듈 : HTTP 프로토콜 처리와 관련된 저수준 클라이언트 기능 제공.
# - urllib 피키지 : 클라이언트에서 공통으로 요구하는 함수, 클래스 등 제공.

# %% [markdown]
# ### urlparse() 함수
# url 파싱한 결과로 ParseResult 인스턴스 반환.

# %%
urlopen(url,data=None,[Timeout])
# 디폴트 : GET
# Timeout : 응답 기다리는 타임아웃 시간.

# %%
# urlopen() 함수 - GET 방식 요청
from urllib.request import urlopen
f = urlopen("https://www.example.com")
print(f.read(500).decode('utf-8'))
# Out:
# <!doctype html>
# <html>
# <head>
#     <title>Example Domain</title>
#
#     <meta charset="utf-8" />
#     <meta http-equiv="Content-type" content="text/html; charset=utf-8" />
#     <meta name="viewport" content="width=device-width, initial-scale=1" />
#     <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
